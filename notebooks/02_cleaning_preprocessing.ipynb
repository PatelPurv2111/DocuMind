# %%
import sys
sys.path.append("..")

from src.data.cleaner import clean_text
from src.data.document_loader import load_documents
from src.config.settings import settings

docs = load_documents(settings.RAW_DATA_PATH)

print("Original text preview:\n")
print(docs[0][:500])

cleaned_docs = [clean_text(doc) for doc in docs]

print("\nCleaned text preview:\n")
print(cleaned_docs[0][:500])

print("\nTotal Cleaned Documents:", len(cleaned_docs))
# Out:
# Original text preview:
#
# Artificial Intelligence, Machine Learning, Natural Language Processing, and Data Science are rapidly transforming the modern technological landscape. These disciplines work together to extract insights from data, automate decision making, and build intelligent systems capable of performing complex tasks that traditionally required human intelligence.
#
# Artificial Intelligence is a broad field focused on designing systems that can simulate aspects of human reasoning, learning, and perception. AI a
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 13
#      10 print("Original text preview:\n")
#      11 print(docs[0][:500])
# ---> 13 cleaned_docs = [clean_text(doc) for doc in docs]
#      15 print("\nCleaned text preview:\n")
#      16 print(cleaned_docs[0][:500])
#
# File ~/Desktop/DocuMind/Project/DocuMind/notebooks/../src/data/cleaner.py:5, in clean_text(text)
#       3 text=text.lower()
#       4 text=re.sub(r"\n", " ",text)
# ----> 5 text-re.sub(r"\s+"," ",text)
#       6 return text
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'
