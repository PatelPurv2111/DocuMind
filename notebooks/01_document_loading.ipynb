# %%
import sys
sys.path.append("..")

from src.data.document_loader import load_documents
from src.config.settings import settings

print("Loading documents from:", settings.RAW_DATA_PATH)

docs = load_documents(settings.RAW_DATA_PATH)

print("Total Documents:", len(docs))

print("\nPreview of first document:\n")
print(docs[0][:1000])
# Out:
# Loading documents from: /Users/purv/Desktop/DocuMind/Project/DocuMind/data/raw/sample_docs.txt
# Total Documents: 1
#
# Preview of first document:
#
# Artificial Intelligence, Machine Learning, Natural Language Processing, and Data Science are rapidly transforming the modern technological landscape. These disciplines work together to extract insights from data, automate decision making, and build intelligent systems capable of performing complex tasks that traditionally required human intelligence.
#
# Artificial Intelligence is a broad field focused on designing systems that can simulate aspects of human reasoning, learning, and perception. AI applications include speech recognition, image classification, recommendation systems, autonomous vehicles, and conversational agents. Over the last decade, the availability of massive datasets and high computational power has accelerated AI research and practical deployment across industries.
#
# Machine Learning is a subset of artificial intelligence that focuses on building models that learn patterns from data. Instead of writing explicit rules for every situation, machine learning algorithms lea
